# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from pylab import rcParams
rcParams['figure.figsize'] = 14, 10

# %%
games = pd.read_csv("data/games-clean.csv")
games.head()
# Out:
#                  home               away  score  attend  \
# 0  Villa Lidköping BK        Bollnäs GIF  8 - 6    3021
# 1           IK Sirius  Sandvikens AIK/BK  5 - 1    1759
# 2      Västerås SK/BK          IF Boltic  9 - 3    1836
# 3         Hammarby IF         Edsbyns IF  6 - 5    3511
# 4         IFK Kungälv  Broberg/Söderhamn  2 - 7     821
#
#                           ref season       start_datetime  start_date  \
# 0                Roland Fager  s1011  2010-10-27 19:00:00  2010-10-27
# 1               Thomas Nordin  s1011  2010-10-27 19:00:00  2010-10-27
# 2             Ronny Andersson  s1011  2010-10-28 19:00:00  2010-10-28
# 3               Håkan Sjösten  s1011  2010-10-29 19:00:00  2010-10-29
# 4  Mikael Karlsson (Grästorp)  s1011  2010-10-29 19:00:00  2010-10-29
#
#   start_time  home_score  away_score  home_tk  away_tk outcome
# 0   19:00:00           8           6        1        6       1
# 1   19:00:00           5           1        2       13       1
# ...

# %%
games.describe()
# Out:
#              attend  home_score  away_score     home_tk     away_tk
# count    910.000000  910.000000  910.000000  910.000000  910.000000
# mean    1454.249451    4.906593    3.994505    8.157143    8.157143
# std     1032.077141    2.735309    2.344615    4.918089    4.918089
# min      108.000000    0.000000    0.000000    1.000000    1.000000
# 25%      756.250000    3.000000    2.000000    4.000000    4.000000
# 50%     1211.500000    4.000000    4.000000    7.500000    7.500000
# 75%     1826.500000    6.000000    5.000000   12.000000   12.000000
# max    11890.000000   17.000000   15.000000   18.000000   18.000000

# %%
# 2010 first game
games.loc[games.start_date.isin([
            "2010-10-27", "2010-10-28", "2010-10-29", "2010-10-30",
            "2011-10-25", "2011-10-28", "2011-10-29",
            "2012-10-20", "2012-10-24",
            "2013-10-20", "2013-10-25",
            "2014-10-24"
        ]), "round"] = 1

# %%
games[games.round == 1].groupby("season").sum().attend.plot(kind="bar")

# %%
games[games.round == 1].groupby("season").sum().home_score.plot(kind="bar")

# %%
games[games.round == 1].groupby("outcome").count().home
# Out:
# outcome
# 1    18
# 2     9
# x     8
# Name: home, dtype: int64

# %%
games[(games.round == 1)].groupby("home").count()
# Out:
#                     away  score  attend  ref  season  start_datetime  \
# home
# Bollnäs GIF            4      4       4    4       4               4
# Edsbyns IF             1      1       1    1       1               1
# GAIS Bandy             1      1       1    1       1               1
# Hammarby IF            2      2       2    2       2               2
# IFK Kungälv            2      2       2    2       2               2
# IFK Motala             1      1       1    1       1               1
# IFK Vänersborg         4      4       4    4       4               4
# IK Sirius              4      4       4    4       4               4
# Kalix Bandy            2      2       2    2       2               2
# Ljusdals BK            1      1       1    1       1               1
# Sandvikens AIK/BK      3      3       3    3       3               3
# TB Västerås            1      1       1    1       1               1
# ...
